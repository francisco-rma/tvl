# %%
# %%timeit -r 1 -n 1

import functions as f
from matplotlib import pyplot as plt
import numpy as np

np.set_printoptions(precision=3)

# iter_n: number of iterations to go through

iter_n = 80

# pop_n: number of individuals in the popoulation

pop_n = 1000

# lb: lower bound of talent
# ub: upper bound of talent

lb, ub = 0, 1

# mu: average value of the talent distribution
# std: standard deviation of the talent distribution

mu, std = 0.6, 0.1

# Creating a population with the desired parameters for talent distribution:

    # talent: array containing sorted values of talent

    # t_i: array containing the indices to the unsorted talent array, i.e:

        # talent[t_i[0]] is the talent of the first individual of the population

        # talent[t_i[j-1]] is the talent of the j-th individual of the population

        # talent[t_i[-1]] is the talent of the last individual of the population

talent, t_i = f.populate(pop_n, lb, ub, mu, std)

# le: chance for an individual to go through a lucky event
le = 0.03

# ue: chance for an individual to go through an unlucky event
ue = 0.03

# runs: number of runs to aggregate over
runs = 10000

# Initialize arrays to hold the position and the talent for the most succesful individual of each run:

# mst: Most Successful Talent (talent of the most succesful individual)
mst = np.empty(runs)

# msp: Most Successful Position (final position of the most succesful individual)
msp = np.empty(runs)

# Create an array to store values of talent and position for those who were overall successful:
successful = np.zeros((1, 2))

for i in range(runs):

    final_pos = f.evolution(talent, iter_n, ue, le)

    successful_per_run = np.column_stack((talent[final_pos > 0], final_pos[final_pos > 0]))

    successful = np.concatenate((successful, successful_per_run))

    mst[i] = talent[np.argmax(final_pos)]

    msp[i] = np.max(final_pos)

# msc: Most Successful Capital (final capital of the most succesful individual)
msc = f.cpt_map(msp)
# Out:
# 1min ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %load_ext line_profiler

# %%
# %lprun -f f.evolution f.evolution(talent, iter_n, ue, le)
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.004618 s
# File: /home/fran/tvl/functions.py
# Function: evolution at line 49
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     49                                           def evolution(talent: np.ndarray, time, unlucky_event, lucky_event, history=False):
#     50                                               '''If history=False (default behavior), returns a 1d array representing the population's final position.
#     51
#     52                                                  If history=True, returns a 2d array where:
#     53                                                       - The i-th row represent the time evolution of the i-th individual's position
#     54                                                       - The j-th column represents the population's position at the j-th iteration
#     55                                                       - The element (i, j) represents the position of the i-th individual at the j-th iteration
#     56                                               '''
#     57
#     58         1        285.0    285.0      6.2      rng = default_rng()
#     59
#     60         1        663.0    663.0     14.4      pos = np.zeros((len(talent), time))
#     61
#     62                                               # Initializing all individuals to a starting position of 0:
#     63
#     64         1        176.0    176.0      3.8      np.place(pos[:, 0], mask=np.zeros(len(talent)) == 0, vals=0)
#     65
#     66         1          1.0      1.0      0.0      if history:
#     67                                                   # Returns a 2d array where:
#     68                                                       # The i-th row represent the time evolution of the i-th individual's position
#     69                                                       # The j-th column represents the population's position at the j-th iteration
#     70                                                       # The element (i, j) represents the position of the i-th individual at the j-th iteration
#     71
#     72                                                   for i in range(time - 1):
#     73                                                       a = rng.uniform(0.0, 1.0, size=len(talent))
#     74                                                       b = rng.uniform(0.0, 1.0, size=len(talent))
#     75
#     76                                                       arr_source = pos[:, i]
#     77
#     78                                                       # Creating logical masks for each scenario:
#     79
#     80                                                           # Scenario 1: individual went through an unlucky event
#     81
#     82                                                       unlucky_mask = a < unlucky_event
#     83
#     84                                                           # Scenario 2: individual went through a lucky event and capitalized
#     85
#     86                                                       lucky_mask = ((a >= unlucky_event) &
#     87                                                                     (a < unlucky_event + lucky_event) &
#     88                                                                     (b < talent)
#     89                                                                     )
#     90
#     91                                                           # Scenario 3: individual didn't go through any events OR went through a lucky event and failed to capitalize:
#     92
#     93                                                       neutral_mask = ((a >= unlucky_event + lucky_event) |
#     94                                                                       ((a >= unlucky_event) &
#     95                                                                       (a < unlucky_event + lucky_event) &
#     96                                                                       (b > talent))
#     97                                                                       )
#     98
#     99                                                       # Upadting position of those in scenario 1:
#    100
#    101                                                       unlucky_vals = np.extract(unlucky_mask, arr_source) - 1
#    102
#    103                                                       np.place(pos[:, i + 1], mask=unlucky_mask, vals=unlucky_vals)
#    104
#    105                                                       # Upadting position of those in scenario 2:
#    106
#    107                                                       lucky_vals = np.extract(lucky_mask, arr_source) + 1
#    108
#    109                                                       np.place(pos[:, i + 1], mask=lucky_mask, vals=lucky_vals)
#    110
#    111                                                       # Upadting position of those in scenario 3:
#    112
#    113                                                       neutral_vals = np.extract(neutral_mask, arr_source)
#    114
#    115                                                       np.place(pos[:, i + 1], mask=neutral_mask, vals=neutral_vals)
#    116
#    117                                                   return pos
#    118
#    119                                               else:
#    120                                                   # Default behavior
#    121                                                   # Returns a 1d array representing the population's final position
#    122
#    123         1          0.0      0.0      0.0          iter = 0
#    124         1          1.0      1.0      0.0          arr_source = pos[:, 0]
#    125
#    126        81         41.0      0.5      0.9          while iter < time:
#    127
#    128        80        737.0      9.2     16.0              a = rng.uniform(0.0, 1.0, size=len(talent))
#    129        80        675.0      8.4     14.6              b = rng.uniform(0.0, 1.0, size=len(talent))
#    130
#    131                                                       # Creating logical masks for each scenario:
#    132
#    133                                                           # Scenario 1: individual went through an unlucky event
#    134        80        194.0      2.4      4.2              unlucky_mask = a < unlucky_event
#    135
#    136                                                           # Scenario 2: individual went through a lucky event AND capitalized
#    137       240        518.0      2.2     11.2              lucky_mask = ((a >= unlucky_event) &
#    138        80        160.0      2.0      3.5                            (a < unlucky_event + lucky_event) &
#    139        80        130.0      1.6      2.8                            (b <= talent))
#    140
#    141                                                           # Scenario 3: individual didn't go through any events OR went through a lucky event and failed to capitalize.
#    142                                                           # No mask is neede because no updates are done.
#    143
#    144                                                       # Upadting position of those in scenario 1:
#    145        80        619.0      7.7     13.4              arr_source[unlucky_mask] = arr_source[unlucky_mask] - 1
#    146
#    147                                                       # Upadting position of those in scenario 2:
#    148        80        379.0      4.7      8.2              arr_source[lucky_mask] = arr_source[lucky_mask] + 1
#    149
#    150        80         39.0      0.5      0.8              iter += 1
#    151
#    152         1          0.0      0.0      0.0      return arr_source
